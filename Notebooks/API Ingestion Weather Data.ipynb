# %%
import requests
import json
import pandas as pd


response = requests.get('https://wttr.in/Delhi?format=j1')

if response.status_code == 200:
    data = response.text
    print("data has been read and saved in to data variable")
else:
    print("Error:", response.status_code)

# %%
df = spark.createDataFrame([data])
